# %%
import pandas as pd
from pathlib import Path

data = Path("Resources/NPSAcreage-09-30-2024.xlsx")
df = pd.read_excel(data) 
df
# Out:
#     National Park Service - Listing of Acreage - 09-30/2024 Unnamed: 1  \
# 0                                            Area Name          Region
# 1                                A LINCOLN BIRTHPL NHP               1
# 2                                            ACADIA NP               1
# 3                                            ADAMS NHP               1
# 4                             AFRICAN BURIAL GROUND NM               1
# ..                                                 ...             ...
# 439  3/ WHISKEYTOWN-SHASTA-TRINITY NRA - SHASTA AND...             NaN
# 440  4/ APPALACHIAN NS TRAIL - MANAGEMENT OF TRAIL ...             NaN
# 441  5/ FOR TOTAL ACREAGE OF BIG CYPRESS NATIONAL P...             NaN
# 442  6/ FOR TOTAL ACREAGE OF EVERGLADES NATIONAL PA...             NaN
# 443  REPORT PREPARED BY: NATIONAL PARK SERVICE LAND...             NaN
#
#     Unnamed: 2     Unnamed: 3               Unnamed: 4  \
# 0        State  NPS Fee Acres  NPS Less Than Fee Acres
# ...

# %%
# Delete the first row
df = df.iloc[0:]

# Set the new header
df.columns = df.iloc[0]

# Drop the row that was used as the header
df = df.iloc[1:]

# Reset the index
df.reset_index(drop=True, inplace=True)

df
# Out:
# 0                                            Area Name Region State  \
# 0                                A LINCOLN BIRTHPL NHP      1    KY
# 1                                            ACADIA NP      1    ME
# 2                                            ADAMS NHP      1    MA
# 3                             AFRICAN BURIAL GROUND NM      1    NY
# 4                                 AGATE FOSSIL BEDS NM      5    NE
# ..                                                 ...    ...   ...
# 438  3/ WHISKEYTOWN-SHASTA-TRINITY NRA - SHASTA AND...    NaN   NaN
# 439  4/ APPALACHIAN NS TRAIL - MANAGEMENT OF TRAIL ...    NaN   NaN
# 440  5/ FOR TOTAL ACREAGE OF BIG CYPRESS NATIONAL P...    NaN   NaN
# 441  6/ FOR TOTAL ACREAGE OF EVERGLADES NATIONAL PA...    NaN   NaN
# 442  REPORT PREPARED BY: NATIONAL PARK SERVICE LAND...    NaN   NaN
#
# 0   NPS Fee Acres NPS Less Than Fee Acres Other Federal Fee Acres  \
# 0           344.5                       0                       0
# ...

# %%
#drop rows that have all Null information
clean_df = df.dropna(subset=df.columns[1:], how='all')
clean_df
# Out:
# 0                    Area Name Region State NPS Fee Acres  \
# 0        A LINCOLN BIRTHPL NHP      1    KY         344.5
# 1                    ACADIA NP      1    ME      37500.32
# 2                    ADAMS NHP      1    MA          9.17
# 3     AFRICAN BURIAL GROUND NM      1    NY          0.35
# 4         AGATE FOSSIL BEDS NM      5    NE       2270.33
# ..                         ...    ...   ...           ...
# 430                YOSEMITE NP     10    CA     759690.11
# 431             YUCCA HOUSE NM      7    CO        195.07
# 432  YUKON-CHARLEY RIVERS N PR     11    AK    2195546.98
# 433                    ZION NP      7    UT     143843.31
# 434                      Total    NaN   NaN   80098836.48
#
# 0   NPS Less Than Fee Acres Other Federal Fee Acres Subtotal Federal Acres  \
# 0                         0                       0                  344.5
# 1                   10707.9                   21.77               48229.99
# ...

# %%
#Sort the dataframe from largest to smallest gross area acres

df_sorted = clean_df.sort_values(by='Gross Area Acres', ascending=False)
df_sorted
# Out:
# 0                     Area Name Region     State NPS Fee Acres  \
# 434                       Total    NaN       NaN   80098836.48
# 426        WRANGELL-ST ELIAS NP     11        AK    7956729.18
# 161      GATES OF THE ARCTIC NP     11        AK     7276030.2
# 302           NOATAK N PRESERVE     11        AK    6549220.04
# 425    WRANGELL-ST ELIAS N PRES     11        AK     4323874.4
# ..                          ...    ...       ...           ...
# 381  T ROOSEVELT BIRTHPLACE NHS      1        NY          0.11
# 214             J F KENNEDY NHS      1        MA          0.09
# 258  M MCLEOD BETHUNE HOUSE NHS      1        DC          0.07
# 380           T KOSCIUSZKO NMEM      1        PA          0.02
# 330        POTOMAC HERITAGE NST      1  PA TO VA             0
#
# 0   NPS Less Than Fee Acres Other Federal Fee Acres Subtotal Federal Acres  \
# 434               363579.73               714717.51            81177133.72
# ...
